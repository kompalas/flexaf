# %% [markdown]
# ### HAR dataset

# %%
# wget https://archive.ics.uci.edu/dataset/240/human+activity+recognition+using+smartphones

import os
from src import project_dir
import pandas as pd
import numpy as np

dataset_dir = os.path.join(project_dir, 'data', 'HAR', 'UCI HAR Dataset')

columns=['acc_x', 'acc_y', 'acc_z', 'gyro_x', 'gyro_y', 'gyro_z', 'subject', 'label']

# %%
def extract_har_data(phase='train'):
    assert phase in ['train', 'test'], "Phase must be either 'train' or 'test'."

    phase_dir = os.path.join(dataset_dir, phase)
    files = [f'body_acc_x_{phase}.txt', f'body_acc_y_{phase}.txt', f'body_acc_z_{phase}.txt',
             f'body_gyro_x_{phase}.txt', f'body_gyro_y_{phase}.txt', f'body_gyro_z_{phase}.txt']
    df = pd.DataFrame()

    subjects = np.loadtxt(os.path.join(phase_dir, f'subject_{phase}.txt'), dtype=int)
    labels = np.loadtxt(os.path.join(phase_dir, f'y_{phase}.txt'), dtype=int)

    for file_idx, file in enumerate(files):
        x_file_path = os.path.join(phase_dir, 'Inertial Signals', file)
        if not os.path.exists(x_file_path):
            raise FileNotFoundError(f"File {x_file_path} does not exist.")
        
        data = np.loadtxt(x_file_path)
        column_name = columns[file_idx]

        for i in range(data.shape[0]):
            subject_id = subjects[i]
            label = labels[i]
            if i == 0:
                signal = data[i, :]
                subject_id_array = np.repeat(subject_id, signal.shape[0])
                label_array = np.repeat(label, signal.shape[0])
            else:
                # there is a window overlap of 50%, so we take the second half of every signal except the first
                # merge this with the previous signal
                signal = np.concatenate((signal, data[i, data.shape[1] // 2:]), axis=0)
                subject_id_array = np.concatenate((subject_id_array, np.repeat(subject_id, data.shape[1] // 2)), axis=0)
                label_array = np.concatenate((label_array, np.repeat(label, data.shape[1] // 2)), axis=0)


        # copy the signal to the corresponding column vertically
        df[column_name] = signal

        if file_idx == 0:
            df['subject'] = subject_id_array
            df['label'] = label_array

    # re-organize dataframe columns
    df = df[columns]
    return df

# %%
train_df = extract_har_data(phase='train')
test_df = extract_har_data(phase='test')

# concatenate vertically both dataframes
df = pd.concat([train_df, test_df], axis=0, ignore_index=True)
df.to_csv(os.path.join(project_dir, 'data', 'HAR.csv'), index=False)

# %% [markdown]
# ### WISDM dataset

# %%
# wget https://archive.ics.uci.edu/dataset/507/wisdm+smartphone+and+smartwatch+activity+and+biometrics+dataset

import os
import pandas as pd
import numpy
import re
from src import project_dir

dataset_dir = os.path.join(project_dir, 'data', 'wisdm', 'wisdm-dataset')

individuals = list(range(1600, 1651))  # 1600 to 1650 inclusive
devices = ['phone', 'watch']
sensors = ['accel', 'gyro']


alldf = pd.DataFrame()

for indiv in individuals:
    indiv_df = pd.DataFrame()

    i = 0
    for device in devices:
        for sensor in sensors:
            datadir = os.path.join(dataset_dir, 'raw', device, sensor)
            datafile = os.path.join(datadir, f'data_{indiv}_{sensor}_{device}.txt')
            if not os.path.isfile(datafile):
                raise FileNotFoundError(f"Data file {datafile} does not exist.")

            df = pd.read_csv(datafile, header=None, names=['subject', 'activity', 'timestamp', 'x', 'y', 'z'])
            df[df.columns[-1]] = df[df.columns[-1]].str.rstrip(';') 
            # print(f"Processing indiv {indiv} device {device} sensor {sensor}...")
            # print(f"Data shape: {df.shape}")

            indiv_df[f'{device}_{sensor}_x'] = df['x']
            indiv_df[f'{device}_{sensor}_y'] = df['y']
            indiv_df[f'{device}_{sensor}_z'] = df['z']
            if i == 0:
                indiv_df['subject'] = df['subject']
                indiv_df['label'] = df['activity'].apply(lambda x: ord(x.upper()) - ord('A'))
            i += 1

    # remove NaN rows from indiv_df
    indiv_df = indiv_df.dropna()
    alldf = pd.concat([alldf, indiv_df], axis=0, ignore_index=True)


columns = [col for col in alldf.columns if col not in ['subject', 'label']] + ['subject', 'label']
alldf = alldf[columns]
alldf.to_csv(os.path.join(project_dir, 'data', 'wisdm.csv'), index=False)
# Out:
# Processing indiv 1600 device phone sensor accel...
# Data shape: (64311, 6)
# Processing indiv 1600 device phone sensor gyro...
# Data shape: (64247, 6)
# Processing indiv 1600 device watch sensor accel...
# Data shape: (65462, 6)
# Processing indiv 1600 device watch sensor gyro...
# Data shape: (65435, 6)
# Processing indiv 1601 device phone sensor accel...
# Data shape: (81457, 6)
# Processing indiv 1601 device phone sensor gyro...
# Data shape: (81193, 6)
# Processing indiv 1601 device watch sensor accel...
# Data shape: (64840, 6)
# Processing indiv 1601 device watch sensor gyro...
# Data shape: (64829, 6)
# Processing indiv 1602 device phone sensor accel...
# Data shape: (84890, 6)
# Processing indiv 1602 device phone sensor gyro...
# Data shape: (64286, 6)
# Processing indiv 1602 device watch sensor accel...
# Data shape: (64985, 6)
# Processing indiv 1602 device watch sensor gyro...
# Data shape: (64950, 6)
# Processing indiv 1603 device phone sensor accel...
# Data shape: (81841, 6)
# Processing indiv 1603 device phone sensor gyro...
# Data shape: (81199, 6)
# Processing indiv 1603 device watch sensor accel...
# Data shape: (64865, 6)
# Processing indiv 1603 device watch sensor gyro...
# Data shape: (64851, 6)
# Processing indiv 1604 device phone sensor accel...
# Data shape: (64314, 6)
# Processing indiv 1604 device phone sensor gyro...
# Data shape: (64243, 6)
# Processing indiv 1604 device watch sensor accel...
# Data shape: (64904, 6)
# Processing indiv 1604 device watch sensor gyro...
# Data shape: (64870, 6)
# Processing indiv 1605 device phone sensor accel...
# Data shape: (81281, 6)
# Processing indiv 1605 device phone sensor gyro...
# Data shape: (81181, 6)
# Processing indiv 1605 device watch sensor accel...
# Data shape: (66195, 6)
# Processing indiv 1605 device watch sensor gyro...
# Data shape: (66187, 6)
# Processing indiv 1606 device phone sensor accel...
# Data shape: (64315, 6)
# Processing indiv 1606 device phone sensor gyro...
# Data shape: (64243, 6)
# Processing indiv 1606 device watch sensor accel...
# Data shape: (64890, 6)
# Processing indiv 1606 device watch sensor gyro...
# Data shape: (64854, 6)
# Processing indiv 1607 device phone sensor accel...
# Data shape: (76702, 6)
# Processing indiv 1607 device phone sensor gyro...
# Data shape: (76689, 6)
# Processing indiv 1607 device watch sensor accel...
# Data shape: (65830, 6)
# Processing indiv 1607 device watch sensor gyro...
# Data shape: (65810, 6)
# Processing indiv 1608 device phone sensor accel...
# Data shape: (96523, 6)
# Processing indiv 1608 device phone sensor gyro...
# Data shape: (64249, 6)
# Processing indiv 1608 device watch sensor accel...
# Data shape: (68198, 6)
# Processing indiv 1608 device watch sensor gyro...
# Data shape: (68156, 6)
# Processing indiv 1609 device phone sensor accel...
# Data shape: (61330, 6)
# Processing indiv 1609 device phone sensor gyro...
# Data shape: (60955, 6)
# Processing indiv 1609 device watch sensor accel...
# Data shape: (69657, 6)
# Processing indiv 1609 device watch sensor gyro...
# Data shape: (69631, 6)
# Processing indiv 1610 device phone sensor accel...
# Data shape: (80870, 6)
# Processing indiv 1610 device phone sensor gyro...
# Data shape: (64244, 6)
# Processing indiv 1610 device watch sensor accel...
# Data shape: (64915, 6)
# Processing indiv 1610 device watch sensor gyro...
# Data shape: (64879, 6)
# Processing indiv 1611 device phone sensor accel...
# Data shape: (64314, 6)
# Processing indiv 1611 device phone sensor gyro...
# Data shape: (64247, 6)
# Processing indiv 1611 device watch sensor accel...
# Data shape: (64888, 6)
# Processing indiv 1611 device watch sensor gyro...
# Data shape: (64855, 6)
# Processing indiv 1612 device phone sensor accel...
# Data shape: (64312, 6)
# Processing indiv 1612 device phone sensor gyro...
# Data shape: (64246, 6)
# Processing indiv 1612 device watch sensor accel...
# Data shape: (65286, 6)
# Processing indiv 1612 device watch sensor gyro...
# Data shape: (65250, 6)
# Processing indiv 1613 device phone sensor accel...
# Data shape: (81698, 6)
# Processing indiv 1613 device phone sensor gyro...
# Data shape: (81186, 6)
# Processing indiv 1613 device watch sensor accel...
# Data shape: (64867, 6)
# Processing indiv 1613 device watch sensor gyro...
# Data shape: (64857, 6)
# Processing indiv 1614 device phone sensor accel...
# Data shape: (163768, 6)
# Processing indiv 1614 device phone sensor gyro...
# Data shape: (83427, 6)
# Processing indiv 1614 device watch sensor accel...
# Data shape: (64865, 6)
# Processing indiv 1614 device watch sensor gyro...
# Data shape: (64831, 6)
# Processing indiv 1615 device phone sensor accel...
# Data shape: (64319, 6)
# Processing indiv 1615 device phone sensor gyro...
# Data shape: (64244, 6)
# Processing indiv 1615 device watch sensor accel...
# Data shape: (64905, 6)
# Processing indiv 1615 device watch sensor gyro...
# Data shape: (64869, 6)
# Processing indiv 1616 device phone sensor accel...
# Data shape: (97465, 6)
# Processing indiv 1616 device phone sensor gyro...
# Data shape: (57106, 6)
# Processing indiv 1616 device watch sensor accel...
# Data shape: (61285, 6)
# Processing indiv 1616 device watch sensor gyro...
# Data shape: (61251, 6)
# Processing indiv 1617 device phone sensor accel...
# Data shape: (64305, 6)
# Processing indiv 1617 device phone sensor gyro...
# Data shape: (64246, 6)
# Processing indiv 1617 device watch sensor accel...
# Data shape: (67012, 6)
# Processing indiv 1617 device watch sensor gyro...
# Data shape: (66976, 6)
# Processing indiv 1618 device phone sensor accel...
# Data shape: (60771, 6)
# Processing indiv 1618 device phone sensor gyro...
# Data shape: (60682, 6)
# Processing indiv 1618 device watch sensor accel...
# Data shape: (61298, 6)
# Processing indiv 1618 device watch sensor gyro...
# Data shape: (61264, 6)
# Processing indiv 1619 device phone sensor accel...
# Data shape: (81459, 6)
# Processing indiv 1619 device phone sensor gyro...
# Data shape: (81199, 6)
# Processing indiv 1619 device watch sensor accel...
# Data shape: (64868, 6)
# Processing indiv 1619 device watch sensor gyro...
# Data shape: (64833, 6)
# Processing indiv 1620 device phone sensor accel...
# Data shape: (111026, 6)
# Processing indiv 1620 device phone sensor gyro...
# Data shape: (64312, 6)
# Processing indiv 1620 device watch sensor accel...
# Data shape: (67194, 6)
# Processing indiv 1620 device watch sensor gyro...
# Data shape: (67158, 6)
# Processing indiv 1621 device phone sensor accel...
# Data shape: (81688, 6)
# Processing indiv 1621 device phone sensor gyro...
# Data shape: (81192, 6)
# Processing indiv 1621 device watch sensor accel...
# Data shape: (71372, 6)
# Processing indiv 1621 device watch sensor gyro...
# Data shape: (71336, 6)
# Processing indiv 1622 device phone sensor accel...
# Data shape: (64308, 6)
# Processing indiv 1622 device phone sensor gyro...
# Data shape: (64250, 6)
# Processing indiv 1622 device watch sensor accel...
# Data shape: (64891, 6)
# Processing indiv 1622 device watch sensor gyro...
# Data shape: (64855, 6)
# Processing indiv 1623 device phone sensor accel...
# Data shape: (91143, 6)
# Processing indiv 1623 device phone sensor gyro...
# Data shape: (64281, 6)
# Processing indiv 1623 device watch sensor accel...
# Data shape: (64875, 6)
# Processing indiv 1623 device watch sensor gyro...
# Data shape: (64839, 6)
# Processing indiv 1624 device phone sensor accel...
# Data shape: (64302, 6)
# Processing indiv 1624 device phone sensor gyro...
# Data shape: (64241, 6)
# Processing indiv 1624 device watch sensor accel...
# Data shape: (71272, 6)
# Processing indiv 1624 device watch sensor gyro...
# Data shape: (71239, 6)
# Processing indiv 1625 device phone sensor accel...
# Data shape: (114850, 6)
# Processing indiv 1625 device phone sensor gyro...
# Data shape: (64302, 6)
# Processing indiv 1625 device watch sensor accel...
# Data shape: (66706, 6)
# Processing indiv 1625 device watch sensor gyro...
# Data shape: (66672, 6)
# Processing indiv 1626 device phone sensor accel...
# Data shape: (75034, 6)
# Processing indiv 1626 device phone sensor gyro...
# Data shape: (69581, 6)
# Processing indiv 1626 device watch sensor accel...
# Data shape: (67306, 6)
# Processing indiv 1626 device watch sensor gyro...
# Data shape: (67272, 6)
# Processing indiv 1627 device phone sensor accel...
# Data shape: (155101, 6)
# Processing indiv 1627 device phone sensor gyro...
# Data shape: (64336, 6)
# Processing indiv 1627 device watch sensor accel...
# Data shape: (64897, 6)
# Processing indiv 1627 device watch sensor gyro...
# Data shape: (64863, 6)
# Processing indiv 1628 device phone sensor accel...
# Data shape: (108362, 6)
# Processing indiv 1628 device phone sensor gyro...
# Data shape: (64283, 6)
# Processing indiv 1628 device watch sensor accel...
# Data shape: (70384, 6)
# Processing indiv 1628 device watch sensor gyro...
# Data shape: (70348, 6)
# Processing indiv 1629 device phone sensor accel...
# Data shape: (139346, 6)
# Processing indiv 1629 device phone sensor gyro...
# Data shape: (128500, 6)
# Processing indiv 1629 device watch sensor accel...
# Data shape: (129808, 6)
# Processing indiv 1629 device watch sensor gyro...
# Data shape: (129738, 6)
# Processing indiv 1630 device phone sensor accel...
# Data shape: (64298, 6)
# Processing indiv 1630 device phone sensor gyro...
# Data shape: (64246, 6)
# Processing indiv 1630 device watch sensor accel...
# Data shape: (64897, 6)
# Processing indiv 1630 device watch sensor gyro...
# Data shape: (64860, 6)
# Processing indiv 1631 device phone sensor accel...
# Data shape: (64315, 6)
# Processing indiv 1631 device phone sensor gyro...
# Data shape: (64246, 6)
# Processing indiv 1631 device watch sensor accel...
# Data shape: (64896, 6)
# Processing indiv 1631 device watch sensor gyro...
# Data shape: (64859, 6)
# Processing indiv 1632 device phone sensor accel...
# Data shape: (64306, 6)
# Processing indiv 1632 device phone sensor gyro...
# Data shape: (64252, 6)
# Processing indiv 1632 device watch sensor accel...
# Data shape: (64892, 6)
# Processing indiv 1632 device watch sensor gyro...
# Data shape: (64858, 6)
# Processing indiv 1633 device phone sensor accel...
# Data shape: (85955, 6)
# Processing indiv 1633 device phone sensor gyro...
# Data shape: (64244, 6)
# Processing indiv 1633 device watch sensor accel...
# Data shape: (64890, 6)
# Processing indiv 1633 device watch sensor gyro...
# Data shape: (64854, 6)
# Processing indiv 1634 device phone sensor accel...
# Data shape: (64309, 6)
# Processing indiv 1634 device phone sensor gyro...
# Data shape: (64247, 6)
# Processing indiv 1634 device watch sensor accel...
# Data shape: (64906, 6)
# Processing indiv 1634 device watch sensor gyro...
# Data shape: (64871, 6)
# Processing indiv 1635 device phone sensor accel...
# Data shape: (128852, 6)
# Processing indiv 1635 device phone sensor gyro...
# Data shape: (64535, 6)
# Processing indiv 1635 device watch sensor accel...
# Data shape: (64893, 6)
# Processing indiv 1635 device watch sensor gyro...
# Data shape: (64858, 6)
# Processing indiv 1636 device phone sensor accel...
# Data shape: (64308, 6)
# Processing indiv 1636 device phone sensor gyro...
# Data shape: (64244, 6)
# Processing indiv 1636 device watch sensor accel...
# Data shape: (64892, 6)
# Processing indiv 1636 device watch sensor gyro...
# Data shape: (64857, 6)
# Processing indiv 1637 device phone sensor accel...
# Data shape: (64801, 6)
# Processing indiv 1637 device phone sensor gyro...
# Data shape: (64766, 6)
# Processing indiv 1637 device watch sensor accel...
# Data shape: (151844, 6)
# Processing indiv 1637 device watch sensor gyro...
# Data shape: (71414, 6)
# Processing indiv 1638 device phone sensor accel...
# Data shape: (64830, 6)
# Processing indiv 1638 device phone sensor gyro...
# Data shape: (64794, 6)
# Processing indiv 1638 device watch sensor accel...
# Data shape: (160799, 6)
# Processing indiv 1638 device watch sensor gyro...
# Data shape: (71426, 6)
# Processing indiv 1639 device phone sensor accel...
# Data shape: (64840, 6)
# Processing indiv 1639 device phone sensor gyro...
# Data shape: (64808, 6)
# Processing indiv 1639 device watch sensor accel...
# Data shape: (151846, 6)
# Processing indiv 1639 device watch sensor gyro...
# Data shape: (75868, 6)
# Processing indiv 1640 device phone sensor accel...
# Data shape: (64845, 6)
# Processing indiv 1640 device phone sensor gyro...
# Data shape: (64809, 6)
# Processing indiv 1640 device watch sensor accel...
# Data shape: (160788, 6)
# Processing indiv 1640 device watch sensor gyro...
# Data shape: (71415, 6)
# Processing indiv 1641 device phone sensor accel...
# Data shape: (160798, 6)
# Processing indiv 1641 device phone sensor gyro...
# Data shape: (75893, 6)
# Processing indiv 1641 device watch sensor accel...
# Data shape: (64821, 6)
# Processing indiv 1641 device watch sensor gyro...
# Data shape: (64787, 6)
# Processing indiv 1642 device phone sensor accel...
# Data shape: (142929, 6)
# Processing indiv 1642 device phone sensor gyro...
# Data shape: (71426, 6)
# Processing indiv 1642 device watch sensor accel...
# Data shape: (60156, 6)
# Processing indiv 1642 device watch sensor gyro...
# Data shape: (60119, 6)
# Processing indiv 1643 device phone sensor accel...
# Data shape: (151834, 6)
# Processing indiv 1643 device phone sensor gyro...
# Data shape: (75872, 6)
# Processing indiv 1643 device watch sensor accel...
# Data shape: (64827, 6)
# Processing indiv 1643 device watch sensor gyro...
# Data shape: (64792, 6)
# Processing indiv 1644 device phone sensor accel...
# Data shape: (160771, 6)
# Processing indiv 1644 device phone sensor gyro...
# Data shape: (75881, 6)
# Processing indiv 1644 device watch sensor accel...
# Data shape: (70358, 6)
# Processing indiv 1644 device watch sensor gyro...
# Data shape: (70323, 6)
# Processing indiv 1645 device phone sensor accel...
# Data shape: (160783, 6)
# Processing indiv 1645 device phone sensor gyro...
# Data shape: (80347, 6)
# Processing indiv 1645 device watch sensor accel...
# Data shape: (67696, 6)
# Processing indiv 1645 device watch sensor gyro...
# Data shape: (67662, 6)
# Processing indiv 1646 device phone sensor accel...
# Data shape: (160792, 6)
# Processing indiv 1646 device phone sensor gyro...
# Data shape: (80347, 6)
# Processing indiv 1646 device watch sensor accel...
# Data shape: (64808, 6)
# Processing indiv 1646 device watch sensor gyro...
# Data shape: (64772, 6)
# Processing indiv 1647 device phone sensor accel...
# Data shape: (81887, 6)
# Processing indiv 1647 device phone sensor gyro...
# Data shape: (81191, 6)
# Processing indiv 1647 device watch sensor accel...
# Data shape: (65526, 6)
# Processing indiv 1647 device watch sensor gyro...
# Data shape: (65501, 6)
# Processing indiv 1648 device phone sensor accel...
# Data shape: (160791, 6)
# Processing indiv 1648 device phone sensor gyro...
# Data shape: (80348, 6)
# Processing indiv 1648 device watch sensor accel...
# Data shape: (64833, 6)
# Processing indiv 1648 device watch sensor gyro...
# Data shape: (64801, 6)
# Processing indiv 1649 device phone sensor accel...
# Data shape: (81975, 6)
# Processing indiv 1649 device phone sensor gyro...
# Data shape: (81201, 6)
# Processing indiv 1649 device watch sensor accel...
# Data shape: (65166, 6)
# Processing indiv 1649 device watch sensor gyro...
# Data shape: (65131, 6)
# Processing indiv 1650 device phone sensor accel...
# Data shape: (160779, 6)
# Processing indiv 1650 device phone sensor gyro...
# Data shape: (80348, 6)
# Processing indiv 1650 device watch sensor accel...
# Data shape: (66592, 6)
# Processing indiv 1650 device watch sensor gyro...
# Data shape: (66556, 6)

# %% [markdown]
# ### HARTH dataset

# %%
# wget https://archive.ics.uci.edu/static/public/779/harth.zip

import os
import pandas as pd
from src import project_dir

datadir = os.path.join(project_dir, 'data', 'harth')

dataset = pd.DataFrame()
for csv_file in os.listdir(datadir):
    if not csv_file.endswith('.csv'):
        continue
    csv_path = os.path.join(datadir, csv_file)
    df = pd.read_csv(csv_path)
    subject = csv_file.replace('.csv', '')

    # Add a subject column to the dataframe
    df['subject'] = subject
    dataset = pd.concat([dataset, df], ignore_index=True)

dataset = dataset.drop(columns=['Unnamed: 0', 'index'], errors='ignore')  # Remove unwanted columns
dataset = dataset.sort_values(by=['subject', 'timestamp'])
dataset.to_csv(os.path.join(project_dir, 'data', 'harth.csv'), index=False)

# %% [markdown]
# ### Coswara dataset

# %%
# check src/misc/extract_coswara.ipynb

# %% [markdown]
# ### DaphNET dataset

# %%
# https://ieeexplore.ieee.org/document/6240371
# wget https://archive.ics.uci.edu/static/public/245/daphnet+freezing+of+gait.zip

import os
import pandas as pd
from src import project_dir

dataset_dir = os.path.join(project_dir, 'data', 'dataset_fog_release', 'dataset')


# Each file comprises the data in a matrix format, with one line per sample, and one column per channel. The channels are as follows:
# Time of sample in millisecond
# Ankle (shank) acceleration - horizontal forward acceleration [mg]
# Ankle (shank) acceleration - vertical [mg]
# Ankle (shank) acceleration - horizontal lateral [mg]
# Upper leg (thigh) acceleration - horizontal forward acceleration [mg]
# Upper leg (thigh) acceleration - vertical [mg]
# Upper leg (thigh) acceleration - horizontal lateral [mg]
# Trunk acceleration - horizontal forward acceleration [mg]
# Trunk acceleration - vertical [mg]
# Trunk acceleration - horizontal lateral [mg]
# Annotations (see Annotations section)

column_names = [
    'time', 'ankle_acc_x', 'ankle_acc_y', 'ankle_acc_z',
    'thigh_acc_x', 'thigh_acc_y', 'thigh_acc_z',
    'trunk_acc_x', 'trunk_acc_y', 'trunk_acc_z', 'annotation',
    'individual'
]

dataset = pd.DataFrame()
results = []
for txt_file in os.listdir(dataset_dir):
    if not txt_file.endswith('.txt'):
        print(f"Skipping non-text file: {txt_file}")
        continue

    file_path = os.path.join(dataset_dir, txt_file)
    with open(file_path, 'r') as f:
        # Read the contents of the text file
        contents = f.read()
        
    # Split the contents into lines
    lines = contents.split('\n')
    # Remove empty lines
    lines = [line for line in lines if line.strip()]

    # iterate over the lines
    for line in lines:
        # Split the line into columns
        columns = line.split(' ')

        value_dict = {
            'time': float(columns[0]),
            'ankle_acc_x': float(columns[1]),
            'ankle_acc_y': float(columns[2]),
            'ankle_acc_z': float(columns[3]),
            'thigh_acc_x': float(columns[4]),
            'thigh_acc_y': float(columns[5]),
            'thigh_acc_z': float(columns[6]),
            'trunk_acc_x': float(columns[7]),
            'trunk_acc_y': float(columns[8]),
            'trunk_acc_z': float(columns[9]),
            'annotation': int(columns[10]), # maybe int?
            'individual': txt_file.replace('.txt', '')
        }
        results.append(value_dict)

dataset = pd.DataFrame(results)
dataset = dataset[column_names]  # Reorder columns
dataset.to_csv(os.path.join(project_dir, 'data', 'daphnet.csv'), index=False)

# %%
dataset.columns
# Out:
# Index(['time', 'ankle_acc_x', 'ankle_acc_y', 'ankle_acc_z', 'thigh_acc_x',
#        'thigh_acc_y', 'thigh_acc_z', 'trunk_acc_x', 'trunk_acc_y',
#        'trunk_acc_z', 'annotation', 'individual'],
#       dtype='object')
